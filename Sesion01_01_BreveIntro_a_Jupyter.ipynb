# %% [markdown]
# <h1 align="center">PROGRAMACIÓN DE COMPUTADORES</h1>
#
# <h2 align="center">UNIVERSIDAD EAFIT</h2>
#
# <h3 align="center">MEDELLÍN - COLOMBIA </h3>

# %% [markdown]
# <h2 align="center">Sesión 01_01 - Introducción a Jupyter</h2>

# %% [markdown]
# # Breve Introducción a Jupyter

# %%
from IPython.display import IFrame
IFrame("https://jupyter.org", 800,600)
#HTML('<iframe src="http://jupyter.org" width="800" height="600"></iframe>')

# %% [markdown]
# ### Ejecución de celdas
#
# Use: Shift + Enter

# %% [markdown]
# ### Markdowns

# %% [markdown]
# # Head 1
# ## Head 2
# ### Head 3
# #### Head 4
#
# Head ===
# ==
# Head ---
# --

# %% [markdown]
# ### Links

# %% [markdown]
# https://www.google.com
#
# [Google](https://www.google.com)
#
# [Google with tooltip](https://www.google.com "Google's Homepage")

# %% [markdown]
# ### Insertando Imágenes

# %% [markdown]
# ![Jupyter](http://jupyter.org/assets/main-logo.svg "Jupyter's homepage")

# %% [markdown]
# ![caldo.JPG](attachment:caldo.JPG)

# %% [markdown]
# ### Tablas

# %% [markdown]
# | Website       | URL           | Rank          |
# | -------------:|:-------------:|--------------:|
# | Google        | google.com    | 1             |
# | Facebook      | facebook.com  | 2             |
# | Youtube       | youtube.com   | 3             |

# %% [markdown]
# ### HTML

# %% [markdown]
# <hr>
# <p> Cualquier tipo de código <strong>HTML</strong> podrá verse bien aquí

# %% [markdown]
# ### Líneas horizontales

# %% [markdown]
# ---
# ***
# ___

# %% [markdown]
# $\LaTeX$

# %% [markdown]
# Inline Fórmula: $z = \sqrt{x^2+y^2}$
#
# Block Fórmula: $$\int_{a+1}^{b-2} f(x)dx$$

# %% [markdown]
# ### Letras Griegas

# %% [markdown]
# - Alpha: $\alpha, A$
# - Beta: $\beta, B$
# - Gamma: $\gamma, \Gamma$
# - Pi: $\pi, \Pi, \varpi$
# - Phi: $\phi, \Phi, \varphi$
# - Epsilon: $\epsilon, \varepsilon$
# - Theta: $\theta, \Theta, \vartheta$
# - Rho: $\rho, \varrho$
# - Sigma: $\sigma, \Sigma, \varsigma$

# %% [markdown]
# ### Operaciones Básicas

# %% [markdown]
# $y = x+5$
#
# $y = x \times z$
#
# $y = x \div z$
#
# $y = \frac{x}{z}$
#
# $$y_n = x_n - x_{n-1}$$
#
# $$y = x^n - 2 \times x^{n-1}$$
#
# $y = \sqrt{\frac{x}{z}}$
#
# $y = \sqrt[3]{\frac{x}{z}}$
#
# $sum = \sum\limits_{a}^{b} t_i$
#
# $int = \int\limits_a^b f(x)dx$

# %% [markdown]
# ### Ayuda Básica

# %%
import sys
import io

# %%
io?

# %% [markdown]
# ### Referencia Rápida en IPython (Jupyter)

# %%
# %quickref

# %% [markdown]
# ### Referencia en Python

# %%
help()

# %%
# %pdoc io.FileIO

# %%
# %pdef io.OpenWrapper

# %% [markdown]
# ### Tab Completion

# %%
# Búsqueda de un objeto con Tab
sys.

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("custom.css", "r").read()
    return HTML(styles)
css_styling()
